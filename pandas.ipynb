# %%
import pandas as pd
# structure data
# data frame

dt={"Name":["aman","gagan","naman","chaman"],"branch":["it","it","cse","ece"],"class":[2,1,3,4],
    "city":["jaipur","aligarh","vrindawan","mathura"]}

df=pd.DataFrame(dt)
df
# Out:
#      Name branch  class       city
# 0    aman     it      2     jaipur
# 1   gagan     it      1    aligarh
# 2   naman    cse      3  vrindawan
# 3  chaman    ece      4    mathura

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df["Name"]      # type is series
# Out:
# 0      aman
# 1     gagan
# 2     naman
# 3    chaman
# Name: Name, dtype: object

# %%
df[["Name","branch"]]    # type is dataframe
# Out:
#      Name branch
# 0    aman     it
# 1   gagan     it
# 2   naman    cse
# 3  chaman    ece

# %%
df.Name
# Out:
# 0      aman
# 1     gagan
# 2     naman
# 3    chaman
# Name: Name, dtype: object

# %%
pd.read_csv()

# %%
filepath=r"C:\Users\Lenovo\OneDrive\Desktop\it\used_bikes.csv"
# when we give the whole path of the address is called absolute path but when we give only name is called relative path
path=r"Used_Bikes.csv"
df=pd.read_csv(path)
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df[['city','price']]
# Out:
#             city     price
# 0      Ahmedabad   35000.0
# 1          Delhi  119900.0
# 2          Delhi  600000.0
# 3      Bangalore   65000.0
# 4      Bangalore   80000.0
# ...          ...       ...
# 32643      Delhi   39000.0
# 32644     Karnal   30000.0
# 32645      Delhi   60000.0
# 32646     Jaipur   15600.0
# 32647       Pune   22000.0
#
# [32648 rows x 2 columns]

# %%
df[0:2]
# Out:
#                             bike_name     price       city  kms_driven  \
# 0  TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1         Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield

# %%
df[2:5]
# Out:
#                               bike_name     price       city  kms_driven  \
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power    brand
# 2  First Owner  8.0  675.0  Triumph
# 3  First Owner  4.0  180.0      TVS
# 4  First Owner  3.0  150.0   Yamaha

# %%
df[2:4]
# Out:
#               bike_name     price       city  kms_driven        owner  age  \
# 2  Triumph Daytona 675R  600000.0      Delhi       110.0  First Owner  8.0
# 3  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0  First Owner  4.0
#
#    power    brand
# 2  675.0  Triumph
# 3  180.0      TVS

# %%
df2=df[2:4]
df2
# Out:
#               bike_name     price       city  kms_driven        owner  age  \
# 2  Triumph Daytona 675R  600000.0      Delhi       110.0  First Owner  8.0
# 3  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0  First Owner  4.0
#
#    power    brand
# 2  675.0  Triumph
# 3  180.0      TVS

# %%
df2[["bike_name",	"price","city","kms_driven"]]
# Out:
#               bike_name     price       city  kms_driven
# 2  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0

# %%
df2=df[1:5]
df2
# Out:
#                               bike_name     price       city  kms_driven  \
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df2[["kms_driven",	"owner",	"age",	"power",	"brand"]]
# Out:
#    kms_driven        owner  age  power          brand
# 1     11000.0  First Owner  4.0  350.0  Royal Enfield
# 2       110.0  First Owner  8.0  675.0        Triumph
# 3     16329.0  First Owner  4.0  180.0            TVS
# 4     10000.0  First Owner  3.0  150.0         Yamaha

# %%
# loc and iloc
df.loc[2:5,["kms_driven","owner","age","power","brand"]]
# Out:
#    kms_driven        owner  age  power    brand
# 2       110.0  First Owner  8.0  675.0  Triumph
# 3     16329.0  First Owner  4.0  180.0      TVS
# 4     10000.0  First Owner  3.0  150.0   Yamaha
# 5     25000.0  First Owner  6.0  150.0   Yamaha

# %%
df.head(20)
# Out:
#                                    bike_name     price       city  kms_driven  \
# 0         TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1                Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                       Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                       TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                           Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6              Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
# 10                  Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore     20000.0
# ...

# %%
df.loc[5:7,["price","city"]]
# Out:
#      price   city
# 5  53499.0  Delhi
# 6  85000.0  Delhi
# 7  45000.0  Delhi

# %%
df.iloc[2:4,3:7]    #loc and iloc is used for slicing
# Out:
#    kms_driven        owner  age  power
# 2       110.0  First Owner  8.0  675.0
# 3     16329.0  First Owner  4.0  180.0

# %%
df.iloc[32644:32647,3:7]
# Out:
#        kms_driven        owner   age  power
# 32644      6639.0  First Owner   9.0  180.0
# 32645     20373.0  First Owner   6.0  220.0
# 32646     84186.0  First Owner  16.0  125.0

# %%
df.loc[32644:32646,["kms_driven","owner","age","power","brand"]]
# Out:
#        kms_driven        owner   age  power  brand
# 32644      6639.0  First Owner   9.0  180.0    TVS
# 32645     20373.0  First Owner   6.0  220.0  Bajaj
# 32646     84186.0  First Owner  16.0  125.0   Hero

# %%
jaipur=df[df["city"]=="Jaipur"]

# %%
jaipur
# Out:
#                          bike_name     price    city  kms_driven  \
# 47      Mahindra Centuro NXT 110cc   28000.0  Jaipur     45000.0
# 134         Suzuki Gixxer SF 150cc   47000.0  Jaipur     70000.0
# 166    Royal Enfield Classic 350cc  123600.0  Jaipur      7702.0
# 189       Harley-Davidson Iron 883  435000.0  Jaipur      5550.0
# 490           Honda CBR 150R 150cc   55000.0  Jaipur      2000.0
# ...                            ...       ...     ...         ...
# 32551    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32570    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32589    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32608    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
# 32646    Hero Super Splendor 125cc   15600.0  Jaipur     84186.0
#
#               owner   age  power            brand
# 47      First Owner   2.0  110.0         Mahindra
# 134     First Owner   6.0  150.0           Suzuki
# ...

# %%
jaipur.shape
# Out:
# (1007, 8)

# %%
jaipur["brand"].nunique()
# Out:
# 13

# %%
jaipur["brand"].unique()
# Out:
# array(['Mahindra', 'Suzuki', 'Royal Enfield', 'Harley-Davidson', 'Honda',
#        'Hero', 'Bajaj', 'KTM', 'Yamaha', 'TVS', 'Benelli', 'Kawasaki',
#        'Hyosung'], dtype=object)

# %%
jaipur["brand"].value_counts()
# Out:
# brand
# Hero               731
# Bajaj               83
# Honda               53
# TVS                 42
# Yamaha              37
# Royal Enfield       29
# KTM                  8
# Harley-Davidson      8
# Mahindra             6
# Suzuki               5
# Benelli              3
# Kawasaki             1
# Hyosung              1
# Name: count, dtype: int64

# %%
jaipur[jaipur["brand"]=="KTM"]
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
# df is the population data and jaipur is the sample data
jaipur_ktm=df[(df["city"]=="Jaipur")&(df["brand"]=="KTM")&(df["owner"]=="First Owner")]
jaipur_ktm
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
jaipur_ktm.to_csv("jaipur_ktm.csv",index=False)

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7324, 8)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
bikenames=df['bike_name']

# %%
df.drop(["bike_name","kms_driven"],axis='columns',inplace=True)

# %%
df.head()
# Out:
#       price       city        owner  age  power          brand
# 0   35000.0  Ahmedabad  First Owner  3.0  110.0            TVS
# 1  119900.0      Delhi  First Owner  4.0  350.0  Royal Enfield
# 2  600000.0      Delhi  First Owner  8.0  675.0        Triumph
# 3   65000.0  Bangalore  First Owner  4.0  180.0            TVS
# 4   80000.0  Bangalore  First Owner  3.0  150.0         Yamaha

# %%
df['dummy']=10

# %%
df.head()
# Out:
#       price       city        owner  age  power          brand  dummy
# 0   35000.0  Ahmedabad  First Owner  3.0  110.0            TVS     10
# 1  119900.0      Delhi  First Owner  4.0  350.0  Royal Enfield     10
# 2  600000.0      Delhi  First Owner  8.0  675.0        Triumph     10
# 3   65000.0  Bangalore  First Owner  4.0  180.0            TVS     10
# 4   80000.0  Bangalore  First Owner  3.0  150.0         Yamaha     10

# %%
df["bikenames"]=bikenames

# %%
df.head()
# Out:
#       price       city        owner  age  power          brand  dummy  \
# 0   35000.0  Ahmedabad  First Owner  3.0  110.0            TVS     10
# 1  119900.0      Delhi  First Owner  4.0  350.0  Royal Enfield     10
# 2  600000.0      Delhi  First Owner  8.0  675.0        Triumph     10
# 3   65000.0  Bangalore  First Owner  4.0  180.0            TVS     10
# 4   80000.0  Bangalore  First Owner  3.0  150.0         Yamaha     10
#
#                               bikenames
# 0    TVS Star City Plus Dual Tone 110cc
# 1           Royal Enfield Classic 350cc
# 2                  Triumph Daytona 675R
# 3                  TVS Apache RTR 180cc
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition

# %%
df.drop(["dummy"],axis="columns",inplace=True)

# %%
df
# Out:
#          price       city        owner  age  power            brand  \
# 0      35000.0  Ahmedabad  First Owner  3.0  110.0              TVS
# 1     119900.0      Delhi  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0      Delhi  First Owner  8.0  675.0          Triumph
# 3      65000.0  Bangalore  First Owner  4.0  180.0              TVS
# 4      80000.0  Bangalore  First Owner  3.0  150.0           Yamaha
# ...        ...        ...          ...  ...    ...              ...
# 9362   25000.0      Delhi  First Owner  8.0  150.0             Hero
# 9369   35000.0  Bangalore  First Owner  9.0  220.0            Bajaj
# 9370  450000.0    Jodhpur  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0  Hyderabad  First Owner  4.0  400.0            Bajaj
# 9372   80000.0  Hyderabad  First Owner  5.0  220.0            Bajaj
#
#                                  bikenames
# 0       TVS Star City Plus Dual Tone 110cc
# 1              Royal Enfield Classic 350cc
# ...

# %%
df[(df["brand"]=="TVS")|(df["brand"]=="Yamaha")|(df["brand"]=="Triumph")|(df["brand"]=="KTM")]
# Out:
#          price         city        owner  age  power    brand  \
# 0      35000.0    Ahmedabad  First Owner  3.0  110.0      TVS
# 2     600000.0        Delhi  First Owner  8.0  675.0  Triumph
# 3      65000.0    Bangalore  First Owner  4.0  180.0      TVS
# 4      80000.0    Bangalore  First Owner  3.0  150.0   Yamaha
# 5      53499.0        Delhi  First Owner  6.0  150.0   Yamaha
# ...        ...          ...          ...  ...    ...      ...
# 9322   58000.0        Delhi  First Owner  2.0  110.0      TVS
# 9336  220000.0        Delhi  First Owner  5.0  320.0   Yamaha
# 9342   55000.0         Pune  First Owner  4.0  150.0   Yamaha
# 9345   78000.0  Kanchipuram  First Owner  3.0  150.0   Yamaha
# 9348  195000.0       Mumbai  First Owner  4.0  390.0      KTM
#
#                                      bikenames
# 0           TVS Star City Plus Dual Tone 110cc
# 2                         Triumph Daytona 675R
# 3                         TVS Apache RTR 180cc
# ...

# %%
brand_ls=["TVS","Yamaha","Triumph","KTM"]
filter_df=df[df["brand"].isin(brand_ls)]

# %%
filter_df.head(30)
# Out:
#         price        city         owner  age  power    brand  \
# 0     35000.0   Ahmedabad   First Owner  3.0  110.0      TVS
# 2    600000.0       Delhi   First Owner  8.0  675.0  Triumph
# 3     65000.0   Bangalore   First Owner  4.0  180.0      TVS
# 4     80000.0   Bangalore   First Owner  3.0  150.0   Yamaha
# 5     53499.0       Delhi   First Owner  6.0  150.0   Yamaha
# 10    72000.0   Bangalore   First Owner  7.0  150.0   Yamaha
# 11    95000.0   Bangalore   First Owner  4.0  250.0   Yamaha
# 24    45000.0       Delhi   First Owner  6.0  150.0   Yamaha
# 31    80000.0     Kaithal  Second Owner  4.0  150.0   Yamaha
# 33   180000.0        Pune   First Owner  4.0  390.0      KTM
# 35    70000.0      Nashik  Second Owner  8.0  200.0      KTM
# 39   179000.0   Bangalore   First Owner  2.0  200.0      KTM
# 50    40000.0      Karnal   First Owner  8.0  150.0   Yamaha
# 52    60000.0      Mumbai   First Owner  5.0  160.0      TVS
# ...

# %%
filter_df.reset_index(drop=True,inplace=True)

# %%
filter_df
# Out:
#          price         city        owner  age  power    brand  \
# 0      35000.0    Ahmedabad  First Owner  3.0  110.0      TVS
# 1     600000.0        Delhi  First Owner  8.0  675.0  Triumph
# 2      65000.0    Bangalore  First Owner  4.0  180.0      TVS
# 3      80000.0    Bangalore  First Owner  3.0  150.0   Yamaha
# 4      53499.0        Delhi  First Owner  6.0  150.0   Yamaha
# ...        ...          ...          ...  ...    ...      ...
# 1523   58000.0        Delhi  First Owner  2.0  110.0      TVS
# 1524  220000.0        Delhi  First Owner  5.0  320.0   Yamaha
# 1525   55000.0         Pune  First Owner  4.0  150.0   Yamaha
# 1526   78000.0  Kanchipuram  First Owner  3.0  150.0   Yamaha
# 1527  195000.0       Mumbai  First Owner  4.0  390.0      KTM
#
#                                      bikenames
# 0           TVS Star City Plus Dual Tone 110cc
# 1                         Triumph Daytona 675R
# 2                         TVS Apache RTR 180cc
# ...
